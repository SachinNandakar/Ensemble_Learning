# %%
# Ensemble Learning models
import pandas as pd
import numpy as np

from sklearn.datasets import load_breast_cancer

bc_data = load_breast_cancer()

# Independent Variables
col = bc_data.feature_names
X = pd.DataFrame(bc_data.data, columns = col)
X.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# ...

# %%
df = pd.DataFrame(bc_data.frame, columns=data.feature_names)
df.head()
# Out:
# Empty DataFrame
# Columns: [mean radius, mean texture, mean perimeter, mean area, mean smoothness, mean compactness, mean concavity, mean concave points, mean symmetry, mean fractal dimension, radius error, texture error, perimeter error, area error, smoothness error, compactness error, concavity error, concave points error, symmetry error, fractal dimension error, worst radius, worst texture, worst perimeter, worst area, worst smoothness, worst compactness, worst concavity, worst concave points, worst symmetry, worst fractal dimension]
# Index: []
#
# [0 rows x 30 columns]

# %%
# Target/Dependent Variables
Y = pd.Categorical.from_codes(breast_cancer.target, breast_cancer.target_names)
Y.unique()
Y.shape

# The target data is categorical and needs encoding
encoder = LabelEncoder()
Y = pd.Series(encoder.fit_transform(Y))
Y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 564    1
# 565    1
# 566    1
# 567    1
# 568    0
# Length: 569, dtype: int32

# %%
# split our dataset as train set and test set.
# X - Independent &  Y-Dependent/Taget

from sklearn.model_selection import train_test_split

train_X, test_X, train_Y, test_Y = train_test_split(X, Y, random_state = 1)

# %%
# Now, will use RandomForestClassifier

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, accuracy_score

Random_Forest_classifier = RandomForestClassifier(max_depth=2, n_estimators=200, random_state=0)
Random_Forest_classifier.fit(train_X, train_Y)

prediction = Random_Forest_classifier.predict(test_X)

confusion_matrix(test_Y, prediction)

accuracy_RFC = accuracy_score(test_Y, prediction)
print("Accuracy Value of Random_Forest_classifier: ",accuracy_RFC)
# Out:
# Accuracy Value of Random_Forest_classifier:  0.9370629370629371

# %%
# Now, will use AdaBoostClassifier

from sklearn.ensemble import AdaBoostClassifier

Ada_Boost_classifier = AdaBoostClassifier(n_estimators=200, random_state=0)
Ada_Boost_classifier.fit(train_X, train_Y)

prediction = Ada_Boost_classifier.predict(test_X)

confusion_matrix(test_Y, prediction)

accuracy_ABC = accuracy_score(test_Y, prediction)
print("Accuracy Value of Ada_Boost_Classifier: ",accuracy_ABC)
# Out:
# Accuracy Value of Ada_Boost_Classifier:  0.965034965034965

# %%
# Now, will use GradientBoostingClassifier

from sklearn.ensemble import GradientBoostingClassifier

Grad_Boost_classifier = GradientBoostingClassifier(n_estimators=200, random_state=0)
Grad_Boost_classifier.fit(train_X, train_Y)

prediction = Grad_Boost_classifier.predict(test_X)

confusion_matrix(test_Y, prediction)

accuracy_GBC = accuracy_score(test_Y, prediction)
print("Accuracy Value of Gradient_Boost_Classifier: ",accuracy_GBC)
# Out:
# Accuracy Value of Gradient_Boost_Classifier:  0.965034965034965
